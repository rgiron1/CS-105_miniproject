# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data Needed.csv")
df
# Out:
#    To which gender identity do you most identify?    What year are you?  \
# 0                                             Man           Fourth Year
# 1                                             Man            Third Year
# 2                                             Man           Fourth Year
# 3                                           Woman            Third Year
# 4                                             Man           Fourth Year
# ..                                            ...                   ...
# 72                                            Man           Fourth Year
# 73                                            Man           Fourth Year
# 74                                            Man           Fourth Year
# 75                                            Man  Fifth Year or higher
# 76                                            Man  Fifth Year or higher
#
#    Are you a transfer student? What is your current GPA?   \
# 0                           No               3.50 to 4.00
# 1                          Yes               3.50 to 4.00
# 2                           No               3.50 to 4.00
# 3                           No               3.50 to 4.00
# 4                          Yes               3.50 to 4.00
# ..                         ...                        ...
# 72                         Yes               3.50 to 4.00
# 73                         Yes               3.50 to 4.00
# 74                          No               3.50 to 4.00
# 75                         Yes               3.00 to 3.49
# 76                         Yes               3.00 to 3.49
#
#    What was your GPA in Fall 2021? What was your GPA in Spring 2021?  \
# 0                     3.50 to 4.00                      3.50 to 4.00
# 1                     3.50 to 4.00                      3.50 to 4.00
# 2                     3.00 to 3.49                      3.00 to 3.49
# 3                     3.50 to 4.00                      3.50 to 4.00
# 4                     3.00 to 3.49                      3.00 to 3.49
# ..                             ...                               ...
# 72                    3.50 to 4.00                      3.50 to 4.00
# 73                    3.50 to 4.00                      3.50 to 4.00
# 74                    3.50 to 4.00                      3.50 to 4.00
# 75                    3.00 to 3.49                      3.00 to 3.49
# 76                    3.00 to 3.49                      3.00 to 3.49
#
#       What is your current housing situation?  \
# 0   On-campus housing (Dorms, Glen Mor, etc.)
# 1   On-campus housing (Dorms, Glen Mor, etc.)
# 2   On-campus housing (Dorms, Glen Mor, etc.)
# 3                              Living at home
# 4                              Living at home
# ..                                        ...
# 72                         Off-campus housing
# 73                         Off-campus housing
# 74  On-campus housing (Dorms, Glen Mor, etc.)
# 75                             Living at home
# 76                             Living at home
#
#    What was your housing situation in Fall 2021? What is your learning style?  \
# 0      On-campus housing (Dorms, Glen Mor, etc.)       Kinesthetic (hands-on)
# 1      On-campus housing (Dorms, Glen Mor, etc.)                       Visual
# 2      On-campus housing (Dorms, Glen Mor, etc.)                          NaN
# 3                                 Living at home       Kinesthetic (hands-on)
# 4                             Off-campus housing       Kinesthetic (hands-on)
# ..                                           ...                          ...
# 72                            Off-campus housing                     Auditory
# 73                            Off-campus housing                        Other
# 74     On-campus housing (Dorms, Glen Mor, etc.)                       Visual
# 75                                Living at home       Kinesthetic (hands-on)
# 76                                Living at home       Kinesthetic (hands-on)
#
#     On average, how many hours are you on campus per day?  \
# 0                                                24.0
# 1                                                24.0
# 2                                                 4.0
# 3                                                 4.0
# 4                                                 0.0
# ..                                                ...
# 72                                                1.0
# 73                                                2.0
# 74                                                4.0
# 75                                                6.0
# 76                                                0.0
#
#     Visual materials (graphs, tables, pictures, etc.) help with my learning.  \
# 0                                                 5.0
# 1                                                 5.0
# 2                                                 5.0
# 3                                                 4.0
# 4                                                 5.0
# ..                                                ...
# 72                                                5.0
# 73                                                5.0
# 74                                                5.0
# 75                                                4.0
# 76                                                4.0
#
#     Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  \
# 0                                                 5.0
# 1                                                 5.0
# 2                                                 5.0
# 3                                                 5.0
# 4                                                 5.0
# ..                                                ...
# 72                                                5.0
# 73                                                5.0
# 74                                                5.0
# 75                                                4.0
# 76                                                5.0
#
#     Verbal activities (discussions, reading aloud, etc.) help with my learning.  \
# 0                                                 5.0
# 1                                                 3.0
# 2                                                 5.0
# 3                                                 2.0
# 4                                                 2.0
# ..                                                ...
# 72                                                5.0
# 73                                                5.0
# 74                                                4.0
# 75                                                3.0
# 76                                                3.0
#
#     Social interactions are better in-person vs. online.  \
# 0                                                 5.0
# 1                                                 1.0
# 2                                                 5.0
# 3                                                 2.0
# 4                                                 4.0
# ..                                                ...
# 72                                                5.0
# 73                                                4.0
# 74                                                4.0
# 75                                                5.0
# 76                                                4.0
#
#     Even though a hybrid option is available, I try to attend in-person classes whenever they are offered.  \
# 0                                                 4.0
# 1                                                 5.0
# 2                                                 5.0
# 3                                                 4.0
# 4                                                 1.0
# ..                                                ...
# 72                                                2.0
# 73                                                3.0
# 74                                                4.0
# 75                                                4.0
# 76                                                1.0
#
#     I feel more productive when attending class in-person vs. online.  \
# 0                                                 5.0
# 1                                                 1.0
# 2                                                 5.0
# 3                                                 3.0
# 4                                                 1.0
# ..                                                ...
# 72                                                4.0
# 73                                                4.0
# 74                                                4.0
# 75                                                5.0
# 76                                                4.0
#
#     I grasp course material better when attending class in-person vs. online.  \
# 0                                                 4.0
# 1                                                 1.0
# 2                                                 5.0
# 3                                                 5.0
# 4                                                 1.0
# ..                                                ...
# 72                                                3.0
# 73                                                4.0
# 74                                                4.0
# 75                                                4.0
# 76                                                4.0
#
#     Overall, I prefer in-person vs. online.
# 0                                       4.0
# 1                                       1.0
# 2                                       5.0
# 3                                       3.0
# 4                                       1.0
# ..                                      ...
# 72                                      2.0
# 73                                      3.0
# 74                                      4.0
# 75                                      4.0
# 76                                      3.0
#
# [77 rows x 18 columns]

# %%
df["Overall, I prefer in-person vs. online."].value_counts()#/df["Overall, I prefer in-person vs. online."].count()
# Out:
# 3.0    20
# 4.0    18
# 5.0    17
# 1.0    12
# 2.0     8
# Name: Overall, I prefer in-person vs. online., dtype: int64

# %%
df["Overall, I prefer in-person vs. online."].replace(3,0,inplace=True)
df["Visual materials (graphs, tables, pictures, etc.) help with my learning."].replace(3,0,inplace=True)
df["Hands-on activities (worksheets, in-person labs, class assignments) help with my learning."].replace(3,0,inplace=True)
df["Verbal activities (discussions, reading aloud, etc.) help with my learning."].replace(3,0,inplace=True)
df["Social interactions are better in-person vs. online."].replace([1,2,3],[-5,-4,0],inplace=True)
df["Even though a hybrid option is available, I try to attend in-person classes whenever they are offered."].replace([1,2,3],[-5,-4,0],inplace=True)
df["I feel more productive when attending class in-person vs. online."].replace([1,2,3],[-5,-4,0],inplace=True)
df["I grasp course material better when attending class in-person vs. online."].replace([1,2,3],[-5,-4,0],inplace=True)
df
# Out:
#    To which gender identity do you most identify?    What year are you?  \
# 0                                             Man           Fourth Year
# 1                                             Man            Third Year
# 2                                             Man           Fourth Year
# 3                                           Woman            Third Year
# 4                                             Man           Fourth Year
# ..                                            ...                   ...
# 72                                            Man           Fourth Year
# 73                                            Man           Fourth Year
# 74                                            Man           Fourth Year
# 75                                            Man  Fifth Year or higher
# 76                                            Man  Fifth Year or higher
#
#    Are you a transfer student? What is your current GPA?   \
# 0                           No               3.50 to 4.00
# 1                          Yes               3.50 to 4.00
# 2                           No               3.50 to 4.00
# 3                           No               3.50 to 4.00
# 4                          Yes               3.50 to 4.00
# ..                         ...                        ...
# 72                         Yes               3.50 to 4.00
# 73                         Yes               3.50 to 4.00
# 74                          No               3.50 to 4.00
# 75                         Yes               3.00 to 3.49
# 76                         Yes               3.00 to 3.49
#
#    What was your GPA in Fall 2021? What was your GPA in Spring 2021?  \
# 0                     3.50 to 4.00                      3.50 to 4.00
# 1                     3.50 to 4.00                      3.50 to 4.00
# 2                     3.00 to 3.49                      3.00 to 3.49
# 3                     3.50 to 4.00                      3.50 to 4.00
# 4                     3.00 to 3.49                      3.00 to 3.49
# ..                             ...                               ...
# 72                    3.50 to 4.00                      3.50 to 4.00
# 73                    3.50 to 4.00                      3.50 to 4.00
# 74                    3.50 to 4.00                      3.50 to 4.00
# 75                    3.00 to 3.49                      3.00 to 3.49
# 76                    3.00 to 3.49                      3.00 to 3.49
#
#       What is your current housing situation?  \
# 0   On-campus housing (Dorms, Glen Mor, etc.)
# 1   On-campus housing (Dorms, Glen Mor, etc.)
# 2   On-campus housing (Dorms, Glen Mor, etc.)
# 3                              Living at home
# 4                              Living at home
# ..                                        ...
# 72                         Off-campus housing
# 73                         Off-campus housing
# 74  On-campus housing (Dorms, Glen Mor, etc.)
# 75                             Living at home
# 76                             Living at home
#
#    What was your housing situation in Fall 2021? What is your learning style?  \
# 0      On-campus housing (Dorms, Glen Mor, etc.)       Kinesthetic (hands-on)
# 1      On-campus housing (Dorms, Glen Mor, etc.)                       Visual
# 2      On-campus housing (Dorms, Glen Mor, etc.)                            0
# 3                                 Living at home       Kinesthetic (hands-on)
# 4                             Off-campus housing       Kinesthetic (hands-on)
# ..                                           ...                          ...
# 72                            Off-campus housing                     Auditory
# 73                            Off-campus housing                        Other
# 74     On-campus housing (Dorms, Glen Mor, etc.)                       Visual
# 75                                Living at home       Kinesthetic (hands-on)
# 76                                Living at home       Kinesthetic (hands-on)
#
#     On average, how many hours are you on campus per day?  \
# 0                                                24.0
# 1                                                24.0
# 2                                                 4.0
# 3                                                 4.0
# 4                                                 0.0
# ..                                                ...
# 72                                                1.0
# 73                                                2.0
# 74                                                4.0
# 75                                                6.0
# 76                                                0.0
#
#     Visual materials (graphs, tables, pictures, etc.) help with my learning.  \
# 0                                                 5.0
# 1                                                 5.0
# 2                                                 5.0
# 3                                                 4.0
# 4                                                 5.0
# ..                                                ...
# 72                                                5.0
# 73                                                5.0
# 74                                                5.0
# 75                                                4.0
# 76                                                4.0
#
#     Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  \
# 0                                                 5.0
# 1                                                 5.0
# 2                                                 5.0
# 3                                                 5.0
# 4                                                 5.0
# ..                                                ...
# 72                                                5.0
# 73                                                5.0
# 74                                                5.0
# 75                                                4.0
# 76                                                5.0
#
#     Verbal activities (discussions, reading aloud, etc.) help with my learning.  \
# 0                                                 5.0
# 1                                                 0.0
# 2                                                 5.0
# 3                                                 2.0
# 4                                                 2.0
# ..                                                ...
# 72                                                5.0
# 73                                                5.0
# 74                                                4.0
# 75                                                0.0
# 76                                                0.0
#
#     Social interactions are better in-person vs. online.  \
# 0                                                 5.0
# 1                                                -5.0
# 2                                                 5.0
# 3                                                -4.0
# 4                                                 4.0
# ..                                                ...
# 72                                                5.0
# 73                                                4.0
# 74                                                4.0
# 75                                                5.0
# 76                                                4.0
#
#     Even though a hybrid option is available, I try to attend in-person classes whenever they are offered.  \
# 0                                                 4.0
# 1                                                 5.0
# 2                                                 5.0
# 3                                                 4.0
# 4                                                -5.0
# ..                                                ...
# 72                                               -4.0
# 73                                                0.0
# 74                                                4.0
# 75                                                4.0
# 76                                               -5.0
#
#     I feel more productive when attending class in-person vs. online.  \
# 0                                                 5.0
# 1                                                -5.0
# 2                                                 5.0
# 3                                                 0.0
# 4                                                -5.0
# ..                                                ...
# 72                                                4.0
# 73                                                4.0
# 74                                                4.0
# 75                                                5.0
# 76                                                4.0
#
#     I grasp course material better when attending class in-person vs. online.  \
# 0                                                 4.0
# 1                                                -5.0
# 2                                                 5.0
# 3                                                 5.0
# 4                                                -5.0
# ..                                                ...
# 72                                                0.0
# 73                                                4.0
# 74                                                4.0
# 75                                                4.0
# 76                                                4.0
#
#     Overall, I prefer in-person vs. online.
# 0                                       4.0
# 1                                       1.0
# 2                                       5.0
# 3                                       0.0
# 4                                       1.0
# ..                                      ...
# 72                                      2.0
# 73                                      0.0
# 74                                      4.0
# 75                                      4.0
# 76                                      0.0
#
# [77 rows x 18 columns]

# %%
df.fillna(0 ,inplace=True)
print(df.loc[[57,65]])
# Out:
#    To which gender identity do you most identify? What year are you?  \
# 57                                            Man         First Year
# 65                                              0                  0
#
#    Are you a transfer student? What is your current GPA?   \
# 57                          No               3.50 to 4.00
# 65                           0                          0
#
#    What was your GPA in Fall 2021? What was your GPA in Spring 2021?  \
# 57                    3.50 to 4.00                                 0
# 65                               0                                 0
#
#       What is your current housing situation?  \
# 57  On-campus housing (Dorms, Glen Mor, etc.)
# 65                                          0
#
#    What was your housing situation in Fall 2021? What is your learning style?  \
# 57     On-campus housing (Dorms, Glen Mor, etc.)                        Other
# 65                                             0                            0
#
#     On average, how many hours are you on campus per day?  \
# 57                                               24.0
# 65                                                0.0
#
#     Visual materials (graphs, tables, pictures, etc.) help with my learning.  \
# 57                                                0.0
# 65                                                0.0
#
#     Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  \
# 57                                                0.0
# 65                                                0.0
#
#     Verbal activities (discussions, reading aloud, etc.) help with my learning.  \
# 57                                                0.0
# 65                                                0.0
#
#     Social interactions are better in-person vs. online.  \
# 57                                                0.0
# 65                                                0.0
#
#     Even though a hybrid option is available, I try to attend in-person classes whenever they are offered.  \
# 57                                                0.0
# 65                                                0.0
#
#     I feel more productive when attending class in-person vs. online.  \
# 57                                                0.0
# 65                                                0.0
#
#     I grasp course material better when attending class in-person vs. online.  \
# 57                                                0.0
# 65                                                0.0
#
#     Overall, I prefer in-person vs. online.
# 57                                      0.0
# 65                                      0.0

# %%
counts = pd.crosstab(df['Overall, I prefer in-person vs. online.'], df['Visual materials (graphs, tables, pictures, etc.) help with my learning.'])
counts
# Out:
# Visual materials (graphs, tables, pictures, etc.) help with my learning.  0.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                         2
# 1.0                                                                         0
# 2.0                                                                         0
# 4.0                                                                         0
# 5.0                                                                         2
#
# Visual materials (graphs, tables, pictures, etc.) help with my learning.  4.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                         8
# 1.0                                                                         3
# 2.0                                                                         2
# 4.0                                                                         5
# 5.0                                                                         6
#
# Visual materials (graphs, tables, pictures, etc.) help with my learning.  5.0
# Overall, I prefer in-person vs. online.
# 0.0                                                                        12
# 1.0                                                                         9
# 2.0                                                                         6
# 4.0                                                                        13
# 5.0                                                                         9

# %%
counts2 = pd.crosstab(df['Overall, I prefer in-person vs. online.'], df['Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.'])
counts2
# Out:
# Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  0.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                                           3
# 1.0                                                                                           0
# 2.0                                                                                           1
# 4.0                                                                                           0
# 5.0                                                                                           1
#
# Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  1.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                                           0
# 1.0                                                                                           0
# 2.0                                                                                           1
# 4.0                                                                                           0
# 5.0                                                                                           0
#
# Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  2.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                                           0
# 1.0                                                                                           1
# 2.0                                                                                           0
# 4.0                                                                                           0
# 5.0                                                                                           0
#
# Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  4.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                                           5
# 1.0                                                                                           2
# 2.0                                                                                           2
# 4.0                                                                                           1
# 5.0                                                                                           5
#
# Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.  5.0
# Overall, I prefer in-person vs. online.
# 0.0                                                                                          14
# 1.0                                                                                           9
# 2.0                                                                                           4
# 4.0                                                                                          17
# 5.0                                                                                          11

# %%
counts3 = pd.crosstab(df['Overall, I prefer in-person vs. online.'], df['Verbal activities (discussions, reading aloud, etc.) help with my learning.'])
counts3
# Out:
# Verbal activities (discussions, reading aloud, etc.) help with my learning.  0.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                           10
# 1.0                                                                            3
# 2.0                                                                            3
# 4.0                                                                            4
# 5.0                                                                            4
#
# Verbal activities (discussions, reading aloud, etc.) help with my learning.  1.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                            2
# 1.0                                                                            2
# 2.0                                                                            1
# 4.0                                                                            2
# 5.0                                                                            1
#
# Verbal activities (discussions, reading aloud, etc.) help with my learning.  2.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                            5
# 1.0                                                                            6
# 2.0                                                                            0
# 4.0                                                                            4
# 5.0                                                                            3
#
# Verbal activities (discussions, reading aloud, etc.) help with my learning.  4.0  \
# Overall, I prefer in-person vs. online.
# 0.0                                                                            2
# 1.0                                                                            0
# 2.0                                                                            3
# 4.0                                                                            3
# 5.0                                                                            5
#
# Verbal activities (discussions, reading aloud, etc.) help with my learning.  5.0
# Overall, I prefer in-person vs. online.
# 0.0                                                                            3
# 1.0                                                                            1
# 2.0                                                                            1
# 4.0                                                                            5
# 5.0                                                                            4

# %%
df[["Visual materials (graphs, tables, pictures, etc.) help with my learning.", "Overall, I prefer in-person vs. online."]].plot.hist(alpha=0.4,range=[0,5])
df[["Hands-on activities (worksheets, in-person labs, class assignments) help with my learning.", "Overall, I prefer in-person vs. online."]].plot.hist(alpha=0.4,range=[0,5])
df[["Verbal activities (discussions, reading aloud, etc.) help with my learning.", "Overall, I prefer in-person vs. online."]].plot.hist(alpha=0.4,range=[0,5])
# Out:
# <AxesSubplot:ylabel='Frequency'>
